# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\chint\\Desktop\\DATA SCIENCE FILES\\INTERNSHIP\\DAILY TASKS\\TASK-7\\data.csv')

# %%
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %% [markdown]
# ## Mean - The mean is the average or the most common value in a collection of numbers.

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\mean.png', width = 400, height = 500)

# %% [markdown]
# ### Mean formula

# %%
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\meanformula.png', width = 400, height = 500)

# %%
# using built in function, here im finding mean only for the 'Mthly_HH_Income' column and skipna means skipping nan values
df['Mthly_HH_Income'].mean(axis = 0, skipna = True)
# Out:
# 41558.0

# %%
# without built-in function
mean = sum(df['Mthly_HH_Income'])/len(df['Mthly_HH_Income'])
print(mean)
# Out:
# 41558.0

# %% [markdown]
# ## Median - The median is the middle number in a group of numbers.

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\median.png')

# %% [markdown]
# ### Median formula

# %%
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\medianformula.png', width = 400, height = 500)

# %%
# using built in function, here im finding mean only for the 'Mthly_HH_Expense' column and skipna means skipping nan values
df['Mthly_HH_Expense'].median(axis = 0, skipna = True)
# Out:
# 15500.0

# %%
# without built-in function
def median(dataset):
    data = sorted(dataset)
    index = len(data) // 2
    
    # If the dataset is odd  
    if len(dataset) % 2 != 0:
        return data[index]
    
    # If the dataset is even
    return (data[index - 1] + data[index]) / 2

# %%
print(median(df['Mthly_HH_Expense']))
# Out:
# 15500.0

# %% [markdown]
# ## Mode - The mode is the value that appears most frequently in a data set.

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\mode.png')

# %%
# using built in function
df['No_of_Fly_Members'].mode()
# Out:
# 0    4
# dtype: int64

# %%
# without built-in function
def mode(dataset):
    frequency = {}

    for value in dataset:
        frequency[value] = frequency.get(value, 0) + 1

    most_frequent = max(frequency.values())

    modes = [key for key, value in frequency.items()
                      if value == most_frequent]

    return modes

# %%
print(mode(df['No_of_Fly_Members']))
# Out:
# [4]

# %% [markdown]
# ## Variance - spread of data around the mean.

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\variance.png', width = 400, height = 500)

# %% [markdown]
# ### Variance formula

# %%
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\varianceformula.png', width = 400, height = 500)

# %%
# using built in function
df['Annual_HH_Income'].var()
# Out:
# 102486925397.91666

# %%
def variance(data):
        # Number of observations
        n = len(data)
        # Mean of the data
        mean = sum(data) / n
        # Square deviations
        deviations = [(x - mean) ** 2 for x in data]
        # Variance
        variance = sum(deviations) / n
        return variance

# %%
print(variance(df['Annual_HH_Income']))
# Out:
# 100437186889.95831

# %% [markdown]
# ## Standard Deviation - square root of variance.

# %%
# using built in function
df['Mthly_HH_Income'].std()
# Out:
# 26097.908978713687

# %% [markdown]
# ### Standard deviation formula

# %%
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\Standard-Deviation-Formula-1.png', width = 400, height = 500)

# %%
observation = df['Mthly_HH_Income']
sum=0
for i in range(len(observation)):
    sum+=observation[i]
mean_of_observations = sum/len(observation)
sum_of_squared_deviation = 0
for i in range(len(observation)):
    sum_of_squared_deviation+=(observation[i]- mean_of_observations)**2
Standard_Deviation = ((sum_of_squared_deviation)/len(observation))**0.5
print(Standard_Deviation)
# Out:
# 25835.611779092826

# %% [markdown]
# ## corelation - Correlation is a statistical measure that expresses the extent to which two variables are linearly related.

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\correlation.png', width = 600, height = 500)

# %%
# using built in function
x=df['Mthly_HH_Income']
y=df['Mthly_HH_Expense']
correlation = x.corr(y)
print(correlation)
# Out:
# 0.6492152549316462

# %% [markdown]
# ## Normal Distribution - A normal distribution, sometimes called the bell curve, is a distribution that occurs naturally in many situations. X~N (mean, std) if we can find out the min and max value then we can say it is normal random variable.

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\normal.png', width = 400, height = 500)

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\distribution.png', width = 400, height = 500)

# %% [markdown]
# ## Feature of Normal Distribution

# %% [markdown]
# - The mean, mode and median are all equal.
# - The curve is symmetric at the center (i.e. around the mean, μ).
# - Exactly half of the values are to the left of center and exactly half the values are to the right.
# - The total area under the curve is 1.

# %% [markdown]
# # Positively Skewed & Negatively Skewed Normal Distribution

# %% [markdown]
# ## Skewness
#
# - Skewness refers to a distortion or asymmetry that deviates from the symmetrical bell curve, or normal distribution, in a set of data. If the curve is shifted to the left or to the right, it is said to be skewed.

# %% [markdown]
# ## Negatively Skewed
#
# - A left-skewed distribution has a long left tail. Left-skewed distributions are also called negatively-skewed distributions.

# %% [markdown]
# ## Positively Skewed
#
# - A right-skewed distribution has a long right tail. Right-skewed distributions are also called positive-skew distributions.

# %%
# image
from IPython.display import Image
Image(filename='C:\\Users\\chint\\Desktop\\skewness.png', width = 400, height = 500)

# %% [markdown]
# ## Effect on Mean, Median and Mode due to Skewness
#
# - generally if the distribution of data is skewed to the left, the mean is less than the median, which is often less than the mode. If the distribution of data is skewed to the right, the mode is often less than the median, which is less than the mean.

# %% [markdown]
# ## Explain QQ Plot and show the implementation of the same
#
# - Q-Q plot is a scatterplot created by plotting two sets of quantiles against one another. if all the datapoints forms a straight line after plotting then the distribution is normal distribution.

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py

data_points = np.random.normal(0, 1, 100)

sm.qqplot(data_points, line ='45')
py.show()

# %% [markdown]
# ## Explain Box Cox and show the implementation of the same
#
# - which is used to convert log normal and pareto distributions into normal distributions, it eliminates the outliers.

# %%
#load necessary packages
import numpy as np 
from scipy.stats import boxcox 
import seaborn as sns 

#make this example reproducible
np.random.seed(0)

#generate dataset
data = np.random.exponential(size=1000)

#plot the distribution of data values
sns.distplot(data, hist=False, kde=True)
# Out:
# C:\Users\chint\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#perform Box-Cox transformation on original data
transformed_data, best_lambda = boxcox(data) 

#plot the distribution of the transformed data values
sns.distplot(transformed_data, hist=False, kde=True)
# Out:
# C:\Users\chint\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
